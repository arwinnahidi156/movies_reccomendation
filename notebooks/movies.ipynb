# %%
import pandas as pd 
import numpy as np 
import sklearn

# %%
movies=pd.read_csv("../data/movies.csv")
credits=pd.read_csv("../data/credits.csv")
ratings=pd.read_csv("../data/ratings.csv")

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %% [markdown]
# calculate a weighted rating
#
# WR=(v/(v+m))*R+(m/(v+m))*c

# %% [markdown]
# v-number of votes
#
# m-minimum number of votes required
#
# C-average rating across all movies
#
# R-average rating of the movie

# %%
m=movies['vote_count'].quantile(0.9)
m
# Out:
# np.float64(1838.4000000000015)

# %%
C=movies['vote_average'].mean()
C
# Out:
# np.float64(6.092171559442016)

# %%
def weighted_rating(df,m=m,C=C):
  R=df['vote_average']
  v=df['vote_count']
  wr=(v/(v+m))*R + (m/(m+v))*C
  return wr

# %%
movies['weighted_rating']=movies.apply(weighted_rating,axis=1)

# %%
movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
(movies.vote_average==0).sum()
# Out:
# np.int64(63)

# %%
(movies.vote_count==0).sum()
# Out:
# np.int64(62)

# %%
movies_filtered=movies[movies['vote_count']>=m].copy()
movies_filtered
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4291    1200000  [{"id": 27, "name": "Horror"}, {"id": 9648, "n...
# 4300    1200000  [{"id": 80, "name": "Crime"}, {"id": 53, "name...
# 4302    1200000                    [{"id": 37, "name": "Western"}]
# 4337    1300000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# 4602     350000                      [{"id": 18, "name": "Drama"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
movies_filtered['weighted_rating']=movies_filtered.apply(weighted_rating,axis=1)

# %%
movies_filtered
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4291    1200000  [{"id": 27, "name": "Horror"}, {"id": 9648, "n...
# 4300    1200000  [{"id": 80, "name": "Crime"}, {"id": 53, "name...
# 4302    1200000                    [{"id": 37, "name": "Western"}]
# 4337    1300000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# 4602     350000                      [{"id": 18, "name": "Drama"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
movies_filtered.sort_values("weighted_rating",ascending=False)
# Out:
#          budget                                             genres  \
# 1881   25000000  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 662    63000000                      [{"id": 18, "name": "Drama"}]
# 65    185000000  [{"id": 18, "name": "Drama"}, {"id": 28, "name...
# 3232    8000000  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 96    160000000  [{"id": 28, "name": "Action"}, {"id": 53, "nam...
# ...         ...                                                ...
# 41    200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 337    92000000  [{"id": 28, "name": "Action"}, {"id": 53, "nam...
# 193   130000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 91    165000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 242   120000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                           homepage      id  \
# 1881                                           NaN     278
# ...

# %% [markdown]
# alt way : the right way to do it

# %%
movies_filtered_2=movies[movies['vote_average']!=0].copy()
movies_filtered_2
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
(movies_filtered_2['vote_count']!=0).sum()
# Out:
# np.int64(4740)

# %%
m=movies_filtered_2['vote_count'].quantile(0.9)
m
# Out:
# np.float64(1880.1000000000004)

# %%
C=movies_filtered_2['vote_average'].mean()
C
# Out:
# np.float64(6.173143459915611)

# %%
def weighted_rating(df,m=m,C=C):
  R=df['vote_average']
  v=df['vote_count']
  wr=(v/(v+m))*R + (m/(m+v))*C
  return wr

# %%
movies_filtered_2['weighted_rating']=movies_filtered_2.apply(weighted_rating,axis=1)

# %%
movies_filtered_2.sort_values(by="weighted_rating",ascending=False)[['title','weighted_rating']].head(50)
# Out:
#                                                   title  weighted_rating
# 1881                           The Shawshank Redemption         8.066219
# 662                                          Fight Club         7.945916
# 65                                      The Dark Knight         7.925496
# 3232                                       Pulp Fiction         7.912081
# 96                                            Inception         7.868254
# 3337                                      The Godfather         7.861384
# 95                                         Interstellar         7.815803
# 809                                        Forrest Gump         7.811435
# 329       The Lord of the Rings: The Return of the King         7.735695
# 1990                            The Empire Strikes Back         7.708874
# 262   The Lord of the Rings: The Fellowship of the Ring         7.675518
# 2912                                          Star Wars         7.674007
# ...
